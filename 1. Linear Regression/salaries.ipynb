# %% [markdown]
# # Predict Salary using Years of Experience

# %%
# Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Supress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
salary_dataset_path = 'data/Salary_Data.csv'
# Replace dataset_path with the actual path to the dataset
df = pd.read_csv(salary_dataset_path)
df.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
df.plot.scatter(x="YearsExperience", y="Salary")
# Out:
# <AxesSubplot:xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# ### Add line of best fit

# %%
x= df["YearsExperience"]
y= df["Salary"]

# Find line of best fit
a, b = np.polyfit(x, y, 1)

# Add points to plot
plt.scatter(x, y)

# Add line of best fit to plot
plt.plot(x, a*x+b, color='black')

# %% [markdown]
# ### Assign features as np.arrays for linear regression model

# %%
X = np.array(df['YearsExperience'])
X = X.reshape(-1,1)
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y = np.array(df['Salary'])
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
# Create a linear regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X, y)
# Out:
# LinearRegression()

# %%
new_data = pd.DataFrame({'YearsExperience': [10, 15, 20]})
new_data
# Out:
#    YearsExperience
# 0               10
# 1               15
# 2               20

# %%
predicted_salaries = model.predict(new_data)

# %%
predicted_salaries
# Out:
# array([120291.82341322, 167541.63502049, 214791.44662777])

# %%
new_data['PredictedSalaries'] = pd.Series(predicted_salaries.round(0))

# %%
new_data
# Out:
#    YearsExperience  PredictedSalaries
# 0               10           120292.0
# 1               15           167542.0
# 2               20           214791.0

# %%
plt.scatter(x=df.YearsExperience, y=df.Salary, color='orange')

plt.scatter(x=new_data.YearsExperience, y=predicted_salaries, color='green')

plt.show()

# %% [markdown]
# # Discussion: The predicted salaries for a person with 10, 15, and 20 years of experience are: 120,291, 167,541, and $214,791 respectively.
